# %% [markdown]
# # ***Jupyter-Notebook to Practice Physical Constants Ratios***
#
# ## Dr Francis M. Sanchez's Physical Constants Ratios in Cosmology and MicroPhysics
#
# ### Physical Constants Ratios
#
# Introduction
# ------------
#
# `Jupyter-Notebook Practice Physical Constants Ratios` provides common physical constants ratios.
# Topological Axis Preview
# <img align="left" src="https://raw.githubusercontent.com/LaGuer/Jupyter-Notebook-Practice-Physical-Constants-Ratios/master/AXETOPOL3.png" alt="topological-axis" width="150"/>
#
#
# Installation
# ------------
#
# Run the Jupyter-notebook natively or just try it from your browser [Mybinder.org](https://mybinder.org/v2/gh/LaGuer/Jupyter-Notebook-Practice-Physical-Constants-Ratios/master); it's be made available for Julia 0.7 and later versions, it can be
# installed with
# [Github.com source code](https://github.com/LaGuer/Jupyter-Notebook-Practice-Physical-Constants-Ratios/blob/master/Jupyter-Notebook%20Practice%20Physical%20Constants%20Ratios.ipynb).
# In a browser session open the URL
#
# <a href="https://colab.research.google.com/github/laguer/Jupyter-Notebook-Practice-Physical-Constants-Ratios/blob/master/Jupyter-Notebook%20Practice%20Physical%20Constants%20Ratios.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/LaGuer/Jupyter-Notebook-Practice-Physical-Constants-Ratios/master)
# ```
# Example of jupyter-notebook
#
# ```
#
# Visualization
# -------------
#
#
#
# [![nbviewer](https://img.shields.io/badge/view%20on-nbviewer-brightgreen.svg)](https://nbviewer.jupyter.org/github/LaGuer/Jupyter-Notebook-Practice-Physical-Constants-Ratios/blob/master/Jupyter-Notebook%20Practice%20Physical%20Constants%20Ratios.ipynb)
#
# ### Updated universal constants and particle properties ( thanks to Jean Maruani / Francis M. Sanchez)
# * [The_Dirac_Electron_From_Quantum_Chemistry_to_Holistic_Cosmology @ researchgate](https://www.researchgate.net/publication/287808070_The_Dirac_Electron_From_Quantum_Chemistry_to_Holistic_Cosmology)
# * [Dirac_Electron_From_Quantum_Chemistry_to_Holistic_Cosmology @ Wiley](https://onlinelibrary.wiley.com/doi/abs/10.1002/jccs.201500374)
#
# | Symbol  | Name                                | Formula                  | Dimension      | Value              | Unit            |
# | ------  | ----                                | -------                  | ---------      | -----              | ----            |
# | `π`     | pi                                  | -                        | -              | 3.1415926535897932 | `pure number`   |
# | `e`     | Euler's number                      | -                        | -              | 2.7182817284590452 | `pure number`   |
# | `γ`     | Euler-Mascheroni gamma              | -                        | -              | 0.5772156649015329 | `pure number`   |
# | `26SGP` | 26 sporadic group Product           | -                        | -              | exp(841.2869278)   | `pure number`   |
# | `HFP`   | Happy Family product                | -                        | -              | exp(674.5210288)   | `pure number`   |
# | `O_M`   | Monster Group Cardinal              | -                        | -              | 8.080174248 × 10^53| `pure number`   |
# | `O_B`   | Baby Monster Group Cardinal         | -                        | -              | 4.15478148 × 10^33 | `pure number`   |
# | `j`     | Joel Sternheimer's constant         |$$j=\frac{8𝜋^2}{log(2)}$$ | -              | 113.91063459990004 | `pure number`   |
# | `c`     | Speed of light in vacuum            | -                        | -              | 2.99792458e8       | `m.s^-1`        |
# | `ħ`     | Reduced Planck constant             | ħ=h/2pi                  | -              | 1.054571800e-34    | `m^2 kg s^-1`   |
# | `G'`    | constant of gravitation CODATA2018  | -                        | M^-1L^3T^-2    | 6.67408(31)e-11    | `m^3 kg^-1 s^-2`|
# | `G`     | F.M.Sanchez constant of gravitation | F_gr=Gmm'/ d^2           | M^-1L^3T^-2    | 6.675453818e-11    | `m^3 kg^-1 s^-2`|
# | `a`     | Electric constant                   | a=α^-1  F_qq=ħc/ad^2     | dimensionless  | 137.035999139^-1   | `pure number`   |
# | `R_U`   |Universe Hubble radius (F.M.Sanchez) | R_U=2G.M_U/c)^2          | L              | 1.3065e26          | `m`             |
# | `G_F`   |Fermi Coupling Constant (F.M.Sanchez)| G_F=(ħc)^3/E_F^2         |   ML^5T^-2     | 1.4358509(7)e-62   | `J.m^3`         |
# | `a_G`   |Gravit Sanchez Coupling Constant     | a_G=ħc/Gm_pm_H           | -              | 1.691936465e38     | `pure number`   |
# | `M_U`   | Universe F.M.Sanchez Mass           | M_U=(ħc/G)^2/m_e.m_p.m_H | M              | 8.7936e52          | `kg`            |
# | `t_cc`  | Kotov Cosmic Periodicity            | -                        | s              | 9600.061(2)        | `s`             |
# |`r_H(0)` | Bare Hydrogen radius                |    aħ/m_ec               | L              | 5.291772103e-11    | `m`             |
# | `H`     |Hydrogen-electron mass ratio         |    m_H/m_e               | dimensionless  | 1837.152645        | `m_e`           |
# | `p`     |Proton-electron mass ratio CODATA2018|    m_p/m_e               | dimensionless  | 1836.15267343(11)  | `m_e`           |
# | `n`     |Neutron-electron mass rati CODATA2018|    m_n/m_e               | dimensionless  | 1838.68366173(89)  | `m_e`           |
# | `m_e`   |electron mass CODATA2018             | -                        | M              |9.1093837015(28)e-31| `kg`            |
# | `μ'`    |Muon electron mass ratio CODATA2018  | -                        | dimensionless  |206.7682830(46)     | `m_e`           |
# | `μ`     |Muon mass     (F.M.Sanchez)          | -                        | dimensionless  |206.7682869         | `m_e`           |
# | `f'`    |Strg Nuc Coupling Constant CODATA2014| -                        | dimensionless  |1/0.1181(11)        | `pure number`   |
# | `f`     |Strg Nuc Coupling Constant C.Bizouard|    F^2/2pi(pH)^3/2       | dimensionless  |8.434502892         | `pure number`   |
# | `F'`    |Fermi Constant reduced mass CODAT2014|   E_F / m_ec^2           | dimensionless  |573007.33(25)       | `pure number`   |
# | `F`     |Fermi Constant reduc mass F.M.SANCHEZ| -                        | dimensionless  |573007.3652         | `pure number`   |
# | `d_e`   | electron magnetic moment excess     | -                        | dimensionless  |1.00115965218091(26)| `pure number`   |
# | `θ'`    |CMB Temperature CODATA2014           | -                        | -              |  2.7255(6) K       | `K`             |
# | `θ`     |CMB Temperature F.M.Sanchez          | -                        | -              |  2.725820831 K     | `K`             |
# | `k_B`   |Boltzman Energy-temperature Convers° | -                        | -              | 1.3806488e10-23    | `J K^-1`        |
# | `W`     |Intermed vector boson Red. Mass      | -                        | dimensionless  | 157298(23)         | `pure number`   |
# | `W_s`   |Intermed vector boson Red. Mass Sz   | -                        | dimensionless  | 157340             | `pure number`   |
# | `Z`     |Intermediate vector boson Red. Mass  | -                        | dimensionless  | 178450.0(41)       | `pure number`   |
# | `Z_s`   |Intermed vector boson Red. Mass Sz   | -                        | dimensionless  | 178452             | `pure number`   |
# | `Π±`    |Pion / pi meson Reduced Mass         | -                        | dimensionless  | 273.13203(68)      | `pure number`   |
# | `Π0`    |Pion / pi meson Reduced Mass         | -                        | dimensionless  | 264.1426(18)       | `pure number`   |

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# ## Latex and notations
#
# **Basic Math Symbols**
#
# ≠ ± ∓ ÷ × ∙ – √ ‰ ⊗ ⊕ ⊖ ⊘ ⊙ ≤ ≥ ≦ ≧ ≨ ≩ ≺ ≻ ≼ ≽ ⊏ ⊐ ⊑ ⊒ ² ³ °
#
# **Geometry Symbols**
#
# ∠ ∟ ° ≅ ~ ‖ ⟂ ⫛
#
# **Algebra Symbols**
#
# ≡ ≜ ≈ ∝ ∞ ≪ ≫ ⌊⌋ ⌈⌉ ∘∏ ∐ ∑ ⋀ ⋁ ⋂ ⋃ ⨀ ⨁ ⨂ 𝖕 𝖖 𝖗
#
# **Set Theory Symbols**
#
# ∅ ∖ ∁ ↦ ↣ ∩ ∪ ⊆ ⊂ ⊄ ⊊ ⊇ ⊃ ⊅ ⊋ ⊖ ∈ ∉ ∋ ∌ ℕ ℤ ℚ ℝ ℂ ℵ ℶ ℷ ℸ 𝓟
#
# **Logic Symbols**
#
# ¬ ∨ ∧ ⊕ → ← ⇒ ⇐ ↔ ⇔ ∀ ∃ ∄ ∴ ∵ ⊤ ⊥ ⊢ ⊨ ⫤ ⊣
#
# **Calculus and Analysis Symbols**
#
# ∫ ∬ ∭ ∮ ∯ ∰ ∇ ∆ δ ∂ ℱ ℒ ℓ
#
# **Greek Letters**
#
# 𝛢𝛼 𝛣𝛽 𝛤𝛾 𝛥𝛿 𝛦𝜀𝜖 𝛧𝜁 𝛨𝜂 𝛩𝜃𝜗 𝛪𝜄 𝛫𝜅 𝛬𝜆 𝛭𝜇 𝛮𝜈 𝛯𝜉 𝛰𝜊 𝛱𝜋 𝛲𝜌 𝛴𝜎 𝛵𝜏 𝛶𝜐 𝛷𝜙𝜑 𝛸𝜒 𝛹𝜓 𝛺𝜔

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# ## Examples of LaTex math notations
#
# - Put your LaTeX math inside ```$$ $$```
#
# - Example of notation for:
#
# - $$\sqrt{a_W} = \frac{E_F}{m_e \cdot c^2}$$ type ```$$\sqrt{a_W} = \frac{E_F}{m_e \cdot c^{2}}$$```
#
# - Write your equation in a dedicated cell with latex
#
# Exercice of notation for:
#
# - $$\sqrt{GG_F} = \frac{\frac{ƛ_e^2}{t_{cc}} \cdot ħ}{\sqrt{m_p \cdot m_H}}$$ ```$$\sqrt{GG_F} = \frac{\frac{ƛ_e^2}{t_{cc}} \cdot ħ}{\sqrt{m_p \cdot m_H}}$$```
#
#
# - This translates ```\begin{equation}
#   \frac{\pi_{Pt}}{\pi_{Bb}}\ = 6\cdot\frac{\pi^5}{p_H^9}
# \end{equation}
# ```
#
# - to this:
# \begin{equation}
# \frac{\pi_{Pt}}{\pi_{Bb}}\ = 6\cdot\frac{\pi^5}{p_H^9}
# \end{equation}
#
# ```
# %%latex
# \begin{align}
# \R_U = \frac{2\cdot G\cdot M_U}{c^2} \\
# \M_U = \frac{({ħc}{G})^2}{m_em_pm_h} \\
# \r_H/ƛ_e = frac{\sum\frac{1}{n}{\sum(\frac{1}{n^2})}\\
# \end{align}
# ```
#
# - $$e^{i\pi} = -1$$ type ```$$e^{i\pi} = -1$$```
# ```
#
# - to this:
# - $$\sum{n}(\frac{1}{n})\ ≈ \frac{137}{60} ≈ 2 \times (\pi-2)$$ type ```$$\sum{n}(\frac{1}{n})\ ≈ \frac{137}{60} ≈ 2 \times (\pi-2)$$```

# %%
# %%latex
# \begin{align}
# (ƛ_e/d) ≈ (R /ƛ_e)^2 ≈ ( ƛ_e / ƛ_X)^4 ≈ (λ_{CNB}/ ƛ_e)^8 ≈ (ƛ_e /ƛ_W)^{16} ≈ (2r_{at} /ƛ_e)^{32} ≈ (ƛ_e/l_{Gl})^{64} ≈ (ƛ_{st}/l_e)^{128} ≈ 2^{256}
# \end{align}
# Out:
# \begin{align}
# (ƛ_e/d) ≈ (R /ƛ_e)^2 ≈ ( ƛ_e / ƛ_X)^4 ≈ (λ_{CNB}/ ƛ_e)^8 ≈ (ƛ_e /ƛ_W)^{16} ≈ (2r_{at} /ƛ_e)^{32} ≈ (ƛ_e/l_{Gl})^{64} ≈ (ƛ_{st}/l_e)^{128} ≈ 2^{256}
# \end{align}

# %%
2**256
# Out:
# 115792089237316195423570985008687907853269984665640564039457584007913129639936

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Monster group
# Let's explore O_M the Sporadic Group of order M (https://en.wikipedia.org/wiki/Monster_group)

# %%
# Sporadic Group order M 
2**46 * 3**20 * 5**9 * 7**6 * 11**2 * 13**3 * 17 * 19 * 23 * 29 * 31 * 41 * 47 * 59 * 71
# Out:
# 808017424794512875886459904961710757005754368000000000

# %% [markdown]
# # Baby monster group
# Let's explore O_B Baby Monster Group (https://en.wikipedia.org/wiki/Baby_monster_group)

# %%
# Baby Monster Group https://en.wikipedia.org/wiki/Baby_monster_group
2**41 * 3**13 * 5**6 * 7**2 * 11 * 13 * 17 * 19 * 23 * 31 * 47
# Out:
# 4154781481226426191177580544000000

# %% [markdown]
# # 26 sporadic group Product
# https://en.wikipedia.org/wiki/Sporadic_group

# %%
import math
 math.exp(841.2869278)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-14-4d58f38f18c5> in <module>
#       1 import math
# ----> 2 math.exp(841.2869278)
#
# OverflowError: math range error

# %% [markdown]
# # Happy Family product
# https://en.wikipedia.org/wiki/Sporadic_group

# %%
np.exp(674.5210288)
# Out:
# 8.724905575508271e+292

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Universe Horizon Radius calculus in 3 minutes (method 1)
# $$R_U=\frac{2.\hbar^2}{G.m_e.m_p.m_n}$$

# %%
# !pip install scipy

# %%
from scipy import constants

# %%
R_U=2*constants.hbar**2/(constants.G*constants.m_e*constants.m_p*constants.m_n)
print(R_U)
# Out:
# 1.3058515261319119e+26

# %% [markdown]
# ## One obtains 13.802861522337478 Gly with method 1

# %%
R_U/(constants.light_year*10**9)
# Out:
# 13.802861522337478

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Nambu Universe Radius calculus in 3 minutes (method 2)
# $$R_N=\frac{2.\hbar^2}{G.(m_N)^3}$$

# %% [markdown]
# With Nambu mass $$m_N=m_e.a$$ and $$a=1/\alpha$$

# %%
R_N=2*constants.hbar**2/(constants.G*((1/constants.fine_structure)*constants.m_e)**3)
print(R_N)
# Out:
# 1.7131902573578377e+26

# %%
(1/constants.fine_structure)
# Out:
# 137.0359990836958

# %% [markdown]
# ## One obtains 18.108435308700802 Gly with method 2

# %%
R_N/(constants.light_year*10**9)
# Out:
# 18.108435308700802

# %% [markdown]
# $$R_N'=ƛ_e(2R/R_N)^{210}$$

# %%
R_Nprime=(constants.hbar/(constants.m_e*constants.c))*(2*R/R_N)**210

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Eddington Universe Radius calculus in 3 minutes (method 3)
# $$R_{Edd}=\frac{2.\hbar^2}{G.m_e.m_p^2}$$

# %%
R_Edd=2*constants.hbar**2/(constants.G*constants.m_e*constants.m_p**2)
print(R_Edd)
# Out:
# 1.3076515370853231e+26

# %% [markdown]
# ## One obtains 13.82188765312757 Gly with method 3

# %%
R_Edd/(constants.light_year*10**9)
# Out:
# 13.82188765312757

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Francis M. Sanchez Universe Radius calculus in 3 minutes (method 4)
# $$R_{Francis.M.Sanchez}=ƛ_e.g(6)$$

# %% [markdown]
# With $$g(k)=exp(2^{k+1/2})/k$$ when $$k=6$$

# %% [markdown]
# And $$ƛ_e=\frac{\hbar}{m_e.c}$$ as the reduced Compton electron wavelength radius

# %%
import numpy as np
from scipy import constants
R_FMS=(constants.hbar/(constants.m_e*constants.c))*np.exp(2**(6+(1/2)))/6
print(R_FMS)
# Out:
# 1.307568892158173e+26

# %% [markdown]
# ## One obtains 13.821014095558315 Gly with method 4

# %%
R_FMS/(constants.light_year*10**9)
# Out:
# 13.821014095558315

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Universe Radius calculus based on supernovae 1a (method 5)
# $$R_{S1a}= $$

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Universe Radius calculus based on pi (method 6)
# $$R_{\pi}=ƛ_e.\pi^{155/2}$$

# %%
R_pi=(constants.hbar/(constants.m_e*constants.c))*constants.pi**(155/2)
print(R_pi)
# Out:
# 1.3058148293550039e+26

# %% [markdown]
# ## One obtains 13.802473637099501 Gly with method 6

# %%
R_pi/(constants.light_year*10**9)
# Out:
# 13.802473637099501

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Universe Radius calculus based on 2 (method 7)
# $$R_{2}=ƛ_e.2^{128}$$

# %%
R_2=(constants.hbar/(constants.m_e*constants.c))*2**128
print(R_2)
# Out:
# 1.3140318971018876e+26

# %% [markdown]
# ## One obtains 13.889328111716429 Gly with method 7

# %%
R_2/(constants.light_year*10**9)
# Out:
# 13.889328111716429

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Universe Radius calculus based on Fermion and Kotov period (method 8)
# $$R_{kotov-fermi}=(2.(c.t_k)^2)/(F^2.ƛ_e)$$

# %%
R_kf=(2*(constants.c*9600.6))/(573007.82**2*(constants.hbar/(constants.m_e*constants.c)))
print(R_kf)
# Out:
# 45400591780805.734

# %%
R_kf=2*(constants.c*9600.6)**2/(constants.hbar/(constants.m_e*constants.c)) / 573007.82**2
print(R_kf)
# Out:
# 1.3067141449737733e+26

# %%
constants.fermi/constants.m_e
# Out:
# 1097769105757763.4

# %%
constants.light_year
# Out:
# 9460730472580800.0

# %%
constants.Julian_year
# Out:
# 31557600.0

# %%
R_kf/(constants.light_year*10**9)
# Out:
# 13.811979410690407

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# # Universe Radius calculus based on "a"  (method 9)
# $$R_{a}=ƛ_e.(2.\pi^2.a^3)^5$$

# %%
lambdabare=(constants.hbar/(constants.m_e*constants.c))
print(lambdabare)
# Out:
# 3.8615926796089057e-13

# %%
R_a=(constants.hbar/(constants.m_e*constants.c))*(2*constants.pi**2)*((1/constants.fine_structure)**3)**5
print(R_a)
# Out:
# 8.602333195850391e+20

# %%
R_a=((constants.pi**2*(2*(1/constants.fine_structure)**3))**5)*(constants.hbar/(constants.m_e*constants.c))

# %%
(2*constants.pi**2)*((1/constants.fine_structure)**3)**5
# Out:
# 2.2276645699260076e+33

# %%
R_a/(constants.light_year*10**9)
# Out:
# 13.80417811516134

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# ## Plotting Macro-physics and Micro-physics relations

# %% [markdown]
# ### Dimensional Analysis of singular Macro-physics and Micro-physics relationships

# %% [markdown]
# ### The unit length considered in the topological axis is the Electron Compton Wavelength given by : scipy.constants.hbar / (scipy.constants.c * scipy.constants.m_e)

# %%
# %%time
# %matplotlib inline
#%matplotlib notebook
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

w = 10
h = 7
d = 140
plt.figure(figsize=(w, h), dpi=d)

# x Periodicity
x = [10, 14, 18, 22, 23.333, 25.178, 26]
y = [1.72515, 2.426, 3.12, 3.755, 4.078, 4.363, 4.506]
plt.scatter(x, y,  color="red", lw=1, marker='x', label=r"Macro-Physics, $y = \ln\ln\frac{\lambdabar_{Macro}}{\lambdabar_e}$")

# + Periodicity
x2 = [10, 14, 22, 23.333, 25.178, 30]
y2 = [1.72155, 2.428, 3.78446, 4.048, 4.368, 5.253]
plt.scatter(x2, y2,  color="black", lw=2, marker='+', label=r"Micro-Physics, $y = \ln\ln\frac{\lambdabar_e}{\lambdabar_{micro}}$")

# Green Periodicity
x3 = [14, 30, 31.556]
y3 = [2.51872, 5.199, 5.4321]
plt.scatter(x3, y3,  color="green", lw=2, marker='.', label=r"Holophysics")

# Slope
x4 = [0, 32]
y4 = [0, 5.5452]
plt.plot(x4, y4, color="grey", lw=1, linestyle=':', label=r"Slope ln(2)/4")

# Slope
# Atiyah
x5 = [-0.91 ,0, 1, 2, 3, 3.14, 4, 5, 5.3, 5.7, 6, 7, 7.38, 8]
y5 = [2.7, 5, 10, 20, 100, 300, 600, 10e3, 10e5, 10e10, 10e20, 10e40, 10e80, 10e160]
#x5 = np.arange[0 , 8, 0.2]
x6 = [5.33, 7.38, 8.]
new_xtick_location = [0, 2, 6, 10, 14, 14.56, 18, 22, 25.13, 26, 30]

#offset = -1
#new_fixed_axis = par2.get_grid_helper().new_fixed_axis
#par2.axis["bottom"] = new_fixed_axis(loc="bottom",
#                                     axes=par2,
#                                     offset=(0, offset))


#y5 = [0, 5.5452]
#plt.plot(x4, y4, color="grey", lw=1, linestyle=':', label=r"Slope ln2/4")
#plt.yscale('log')
#plt.loglog(y, y2, y3)
plt.text(18, 1.00, r' MICRO-PHYSICS', fontsize=18, color="black")
plt.text(1, 0.4, r' STRING', fontsize=8, color="black")
plt.text(14, -0.2, r' $𝛾.𝛤$', fontsize=14, color="black")
plt.text(24.4, -0.2, r' $𝛤$', fontsize=14, color="black")
plt.text(6, 1., r' Gluons', fontsize=8, color="black")
plt.text(10, 1.55, r' Mean Pion', fontsize=8, color="black")
plt.text(3.5, 1.70, r' Bohr Atom Diameter', fontsize=8, color="red")
plt.text(4, 2.35, r' Rydberg Reduced Wavelength / $\pi$', fontsize=8, color="red")
plt.text(14, 2.20, r' Half Mean Weak Boson', fontsize=8, color="black")
plt.text(14, 2.52, r'Higgs Boson', fontsize=8, color="green")
plt.text(7, 3.09, r' Cosmic Wavelength hc/2kT, T=2.73 K', fontsize=8, color="red")
plt.text(15, 3.78, r' White Dwarf Diameter', fontsize=8, color="red")
plt.text(22.2, 3.7, r' $BosonX_{GUT}$', fontsize=8, color="black")
plt.text(24, 4.00, r' Photon', fontsize=8, color="black")
plt.text(14.3, 4.05, r' Kotov cycle $*2\pi$a : Stellar System', fontsize=8, color="red")
#plt.text(26, 4.30, r' Graviton /a', fontsize=8, color="green")
plt.text(26, 4.30, r' Graviton /a', fontsize=8, color="black")
plt.text(21, 4.30, r' Galaxy Group', fontsize=8, color="red")
plt.text(18.7, 4.6, r' Hubble Lemaitre radius $*2\pi$', fontsize=8, color="red")
plt.text(28, 5.00, r'Super Cycle', fontsize=8, color="green")
plt.text(30.5, 5.2, r'HOL', fontsize=8, color="black")
plt.text(30, 5.55, r'GRANDCOSMOS', fontsize=8, color="green")
plt.text(-1, 3.50, r' MACRO-PHYSICS', fontsize=18, color="red")
plt.grid(True)
plt.legend(loc=2) # upper left corner
plt.xlabel('Number of peculiar dimensions in the bosonic string theory: n = 4k+2')
plt.ylabel(r'Macro: lnln$\frac{\lambdabar_{Macro}}{\lambdabar_e}$', fontsize=10, color="red")
plt.title('Topological Axis', fontsize=18, color="black")
#plt.arrow(1,30,0,0, head_width=0.05, head_length=0.1, fc='k', ec='k')
ax2 = plt.twinx()
#ax2.plot(x, exp(2)**x, lw=1, color="m")
T=np.arange(len(y5))
ax2.set_yticks(T)
ax2.set_ylabel(r"Micro: $\ln\ln\frac{\lambdabar_e}{\lambda_{micro}}$", fontsize=10, color="black")

#for label in ax2.get_yticklabels():
#    label.set_color("red")
ax3 = plt.twiny()
#ax3.plot(x4, y4, lw=1, color="b")
ax3.set_xlabel(r"Characteristic lengths of physics and cosmology follow the law: $exp(2^{{n}/{4}})$", fontsize=10, color="blue")

for label in ax2.get_xticklabels():
    label.set_color("pink")
#plt.xticks(x5,x5)
#plt.yticks(x5,x5)
ax2.xaxis.set_label_position('top') 
ax2.yaxis.set_label_position('right') 
ax2.tick_params(axis='x', colors="C1")
ax2.tick_params(axis='y', colors="black")
ax2.set_ylim(-0.25,6)
#plt.set_yscale('log', ybase=10)
ax2.set_yscale('linear', ybase=10)
ax2.spines['right'].set_position(('outward', 40))
ax2.spines['bottom'].set_position(('outward', 20))
my_xticks = ['-0.9', '0', '1', '2', '3', '$\pi$', '4', '5', '$16/3$', '$e^{\pi}/{4}$', '6', '7', '$e^2$','']
my_yticks = ['$\e$', 'e', '30', '500', '10e10','10e20', '10e40', '10e80', '10e100', '']
plt.xticks(x5, my_xticks, fontsize=10)
plt.yticks(x5, my_yticks, fontsize=6, color="black")
#plt.yticks(np.arange(min(x5), max(y5), 1e2))

# Turn on the frame for the twin axis, but then hide all 
# but the bottom spine
ax2.set_frame_on(True)
ax2.patch.set_visible(False)
#ax2.patch.set_visible(True)
#for sp in ax2.spines.itervalues():
#    sp.set_visible(False)
#ax2.spines["bottom"].set_visible(True)
ax2.set_xticks(new_xtick_location)
ax2.set_xticklabels(new_xtick_location)
#ax2.grid(True)
ax3.grid(True)
#ax2.set_yticks(y5)
#ax2.set_yticklabels(y5)
#ax2.axis["bottom"].label.set_color(p1.get_color())
#ax2.axis["bottom"].label.set_color(p3.get_color())
#ax2.set_xlabel(r"Modified x-axis: $1/(1+X)$")
#my_x1ticks = ['-1', '0', '1', '2','3', '4', '5', '$16/3$', '$e^{\pi}/{4}$', '6', '7', '$e^2$','']
#plt.xticks(x5, my_x1ticks, fontsize=6)
#plt.arrow(-1, -1010, 4, 10e10, head_width=0.06, head_length=0.1, fc='k', ec='k');
#par2.axis["top"].toggle(all=False)
#par2.set_xlabel("Velocity")
#p1, = host.plot([0, 1, 2], [0, 1, 2], label="Density")
#p3, = par2.plot([50, 30, 15], [0, 1, 2], label="Velocity")
#par2.set_xlim(1, 65)
#host.legend()
#host.axis["bottom"].label.set_color(p1.get_color())
#par2.axis["bottom"].label.set_color(p3.get_color())
plt.show()
# Out:
# CPU times: user 1.73 s, sys: 1.1 s, total: 2.83 s
# Wall time: 2.89 s

# %%
# %%time
# %matplotlib inline
#%matplotlib notebook
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

#w = 6
#h = 7
#d = 140
#plt.figure(figsize=(w, h), dpi=d)
plt.figure()

# x Periodicity
x = [10, 14, 18, 22, 23.333, 25.178, 26]
y = [1.72515, 2.426, 3.12, 3.755, 4.078, 4.363, 4.506]
plt.scatter(x, y,  color="red", lw=1, marker='x', label=r"Macro-physics, $y = \ln\ln\frac{\lambdabar_{Macro}}{\lambdabar_e}$")

# + Periodicity
x2 = [10, 14, 22, 30]
y2 = [1.72155, 2.428, 3.78446, 5.253]
plt.scatter(x2, y2,  color="black", lw=2, marker='+', label=r"Micro-physics, $y = \ln\ln\frac{\lambdabar_e}{\lambdabar_{micro}}$")

# Green Periodicity
x3 = [14, 30, 31.556]
y3 = [2.51872, 5.199, 5.4321]
plt.scatter(x3, y3,  color="green", lw=2, marker='.', label=r"Green Points")

# Slope
x4 = [0, 32]
y4 = [0, 5.5452]
plt.plot(x4, y4, color="red", lw=1, linestyle=':', label=r"Slope ln2/4")

# Atiyah
x5 = [-0.85, 0, 1, 2, 3, 4, 5, 5.33, 6, 7, 7.38, 8.]
#x5 = [0, 1, 2, 3, 4, 5, 5.33, 6, 7, 7.38, 8.]
x6 = [5.33, 7.38, 8.]
x7 = [0, 2, 6, 10, 14, 18, 22, 26, 30, 34]
#y5 = [0, 5.5452]
#plt.scatter(x5, y5, color="red", lw=1, linestyle=':', label=r"Slope ln2/4")
#plt.yscale('log')
#plt.loglog(y, y2, y3)
plt.text(10, 1.55, r' Bohr Atom Diameter', fontsize=8, color="red")
plt.text(5, 1.70, r' Mean Pion', fontsize=8, color="black")
plt.text(4, 2.35, r' Half Mean Weak Boson', fontsize=8, color="black")
plt.text(14, 2.20, r' Rydberg Reduced Wavelength over pi', fontsize=8, color="red")
plt.text(14, 2.52, r'Higgs Boson', fontsize=8, color="green")
plt.text(18, 3.09, r' Cosmic Photon hc/2kT T=2.73 K', fontsize=8, color="red")
plt.text(16, 3.78, r' X Boson GUT', fontsize=8, color="black")
plt.text(22, 3.6, r' White Dwarf Diameter', fontsize=8, color="red")
plt.text(24, 4.10, r' Kotov cycle: Stellar System', fontsize=8, color="red")
plt.text(25, 4.30, r' Milankovich cycle: Galaxy', fontsize=8, color="red")
plt.text(26, 4.48, r' Hubble Diameter x pi', fontsize=8, color="red")
plt.text(28, 4.95, r'Large Periodicity', fontsize=8, color="green")
plt.text(28, 5.25, r'HOL', fontsize=8, color="black")
plt.text(28, 5.65, r'GRANDCOSMOS ∅', fontsize=8, color="green")
plt.grid(True)
plt.legend(loc=2) # upper left corner
plt.xlabel('SuperSpace Index where Super Space Dimension n = 4k+2')
plt.ylabel(r'Micro: $\ln\ln\frac{\lambdabar_e}{\lambda_{micro}}$')
plt.title('Topolog Axis', fontsize=18, color="black")
plt.arrow(1,30,0,0, head_width=0.05, head_length=0.1, fc='k', ec='k')
ax2 = plt.twinx()
#ax2.plot(x, exp(2)**x, lw=1, color="m")
ax2.set_ylabel(r"Macro: lnln$\frac{\lambdabar_{Macro}}{\lambdabar_e}$", fontsize=10, color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")
ax3 = plt.twiny()
#ax3.plot(x4, y4, lw=1, color="b")
ax3.set_xlabel(r"Characteristic lengths of physics and cosmology follow the law: $exp(2**(n/4))$", fontsize=6, color="blue")
for label in ax2.get_xticklabels():
    label.set_color("grey")
ax2.xaxis.set_label_position('top') 
ax2.yaxis.set_label_position('right') 
ax2.tick_params(axis='x', colors="C1")
ax2.tick_params(axis='y', colors="C1")
ax2.set_ylim(10e-5,10e105)
ax2.set_yscale('symlog',basey=10)
ax2.spines['right'].set_position(('outward', 40))
plt.xticks(x5,x5)
#plt.yticks(y,y)
plt.show()
# Out:
# CPU times: user 2.07 s, sys: 637 ms, total: 2.7 s
# Wall time: 3.06 s

# %%
#%matplotlib notebook
# %matplotlib inline
import pylab
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
fig = pylab.figure(figsize=(12, 9))
ax = fig.add_subplot(111, projection = '3d')
x = [0, 10, 10, 14, 14, 14.56, 18, 22, 22, 23.3, 25.17, 26, 30, 30, 31.556]
y = [0, 1, 2, 3, 3, 3.14, 4, 5, 5, 5.33, 5.78, 6, 7, 7, 7.38]
z = [0, np.log(np.log(274.072)), np.log(np.log(268.6)), np.log(np.log(83432)), np.log(np.log(83782)), np.log(np.log(245901)), np.log(np.log(6.842e9)), np.log(np.log(1.3011e19)), np.log(np.log(1.834e19)), np.log(np.log(7.52e24)), np.log(np.log(2.46e36)), np.log(np.log(2.126e39)), np.log(np.log(9.656e82)), np.log(np.log(4.258e78)), np.log(np.log(2.350e99))]
sc = ax.scatter(x,y,z)
# now try to get the display coordinates of the first point

x2, y2, _ = proj3d.proj_transform(10,2,1.72, ax.get_proj())
x3, y3, _ = proj3d.proj_transform(30,7,5, ax.get_proj())
x4, y4, _ = proj3d.proj_transform(14.56,3.14,2.51, ax.get_proj())
x5, y5, _ = proj3d.proj_transform(14,3,2.427, ax.get_proj())
x6, y6, _ = proj3d.proj_transform(23.3,5.3,4.078, ax.get_proj())
x7, y7, _ = proj3d.proj_transform(26,6,4.506, ax.get_proj())

label = pylab.annotate(
    "Mean Pion", 
    xy = (x2, y2), xytext = (-20, 20),
    textcoords = 'offset points', ha = 'right', va = 'bottom',
    bbox = dict(boxstyle = 'round,pad=0.5', fc = 'white', alpha = 0.5),
    arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

label = pylab.annotate(
    "Rydberg Wavelength", 
    xy = (x5, y5), xytext = (-20, 20),
    textcoords = 'offset points', ha = 'right', va = 'bottom',
    bbox = dict(boxstyle = 'round,pad=0.5', fc = 'red', alpha = 0.5),
    arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

label = pylab.annotate(
    "Higgs Boson", 
    xy = (x4, y4), xytext = (-20, 20),
    textcoords = 'offset points', ha = 'right', va = 'bottom',
    bbox = dict(boxstyle = 'round,pad=0.5', fc = 'green', alpha = 0.5),
    arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

label = pylab.annotate(
    "Kotov Cycle * 2pi.a", 
    xy = (x6, y6), xytext = (-20, 20),
    textcoords = 'offset points', ha = 'right', va = 'bottom',
    bbox = dict(boxstyle = 'round,pad=0.5', fc = 'red', alpha = 0.5),
    arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

label = pylab.annotate(
    "Hubble Diameter * 2 pi", 
    xy = (x7, y7), xytext = (-20, 20),
    textcoords = 'offset points', ha = 'right', va = 'bottom',
    bbox = dict(boxstyle = 'round,pad=0.5', fc = 'red', alpha = 0.5),
    arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

label = pylab.annotate(
    "Super Cycle", 
    xy = (x3, y3), xytext = (-20, 20),
    textcoords = 'offset points', ha = 'right', va = 'bottom',
    bbox = dict(boxstyle = 'round,pad=0.5', fc = 'green', alpha = 0.5),
    arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))


def update_position(e):
    x2, y2, _ = proj3d.proj_transform(10,2,1.72, ax.get_proj())
    label.xy = x2,y2
    label.update_positions(fig.canvas.renderer)
    fig.canvas.draw()
    
def update_position(e):
    x3, y3, _ = proj3d.proj_transform(30,7,5, ax.get_proj())
    label.xy = x3,y3
    label.update_positions(fig.canvas.renderer)
    fig.canvas.draw()
    
def update_position(e):
    x4, y4, _ = proj3d.proj_transform(14.56, 3.14, 2.51, ax.get_proj())
    label.xy = x4,y4
    label.update_positions(fig.canvas.renderer)
    fig.canvas.draw()
    
def update_position(e):
    x5, y5, _ = proj3d.proj_transform(14, 3, 2.427, ax.get_proj())
    label.xy = x5,y5
    label.update_positions(fig.canvas.renderer)
    fig.canvas.draw()
    
def update_position(e):
    x6, y6, _ = proj3d.proj_transform(23.3,5.3,4.078, ax.get_proj())
    label.xy = x6,y6
    label.update_positions(fig.canvas.renderer)
    fig.canvas.draw()
    
def update_position(e):
    x7, y7, _ = proj3d.proj_transform(23.3,5.3,4.078, ax.get_proj())
    label.xy = x7,y7
    label.update_positions(fig.canvas.renderer)
    fig.canvas.draw()
    
fig.canvas.mpl_connect('button_release_event', update_position)
pylab.show()

# %%
np.exp (np.euler_gamma)

# %%
# %%latex
# \begin{align}
# \frac{m_p^4}{m_p\cdot m_H\cdot\ m_e} = M \\
# \end{align}
# Out:
# \begin{align}
# \frac{m_p^4}{m_p\cdot m_H\cdot\ m_e} = M \\
# \end{align}

# %% [markdown]
# # Sir Michael Atiyah's key formula
#
# https://www.reddit.com/r/math/comments/9ig4ei/atiyahs_computation_of_the_fine_structure/
#
# $$2Ч = \lim_{n\to\infty}\sum^{j=n}_{j=1} 2^{-j} (1-\int_{1/j}^{j}log_2 x  \mathrm{d}x)$$

# %%
from math import log, pi as π
from numpy import euler_gamma as γ

# Ж = T(π),
# Ч = T(γ) where γ is Euler-Mascheroni’s constant γ
# (1.1) Ч/γ = Ж/π.
# $$int_j^{j+1} log_2 x dx + int_{1/(j+1)}^{1/j} log_2 x dx$$

Ч = sum(2**-j * (1 - ((j + 1/j) * log(j) - j + 1/j) / log(2))
        for j in range(1, 100)) / 2

Ж = π * Ч / γ
α = 1/Ж

print("α alpha =", α)
print("Ж =", Ж)
print("Ч =", Ч)
print("γ =", γ)
# Out:
# α alpha = 6.239867897632327
# Ж = 0.1602598029967017
# Ч = 0.029445086917308665
# γ = 0.5772156649015329

# %%
# %%time
# Inclusions
from math import *
values = []
exponents = []

########################################################
#     Physical Constants Ratios                        #
########################################################

progression_display = True # True / False
exponent_minmax = 3
precision = 0.00000001 # add or remove 0 for precision's accuracy
number_min_Zero = 1

# exercice 1
#exponent_minmax = 4
#precision = 0.00000002
#values.append(['a/137',log(137.0359991)-log(137)])
#values.append(['pg',log(1831.531308)-log(1836.152672)*0])
#values.append(['pK',log(1842.604127)-log(1836.118109)*0])
#values.append(['H',log(1837.152645)-log(1836.118109)*0])
#values.append(['p',log(1836.152672)+log(1836.118109)*0])
#values.append(['n',log(1838.683659)])
#values.append(['1sH-p',-log(0.999973)])
#values.append(['d',log(1.001159652)])

# exercice 2
#exponent_minmax = 3
#precision = 0.00000001
values.append(['pi',1.144729886])
values.append(['a',4.920243658])
values.append(['137',4.919980926])
values.append(['F',13.25865385])
values.append(['H/p',0.00054445428])
values.append(['x',0.002792343634])
values.append(['n',7.516805193])
values.append(['8',2.079441542])
values.append(['d',0.001158980123])
values.append(['Ggamma',3.22597446])

########################################################
#     The Program itself                               #
########################################################

print("Starting CosmHology...")
length = len(values)
precedent=-exponent_minmax

# Min exponent set for each value 
for i in range (0,length):
    exponents.append(-exponent_minmax)
    print(values[i][0],end='\t')

print("Zeros",end='\t');
print("Precision");


nbSolutions = 0
#<= 0 Do not make twice the same calculation with the inverses
while exponents[length-1]<=0:
    # Calculate and process the result
    result= 0
    j=0
    while j<length:
        result=result + (values[j][1])*(exponents[j])
        j+=1
    #if result<0:
    #    result*=(-1)

    # Display or not the results
    if result<=precision and result>=-precision:
        # counting zeros
        nbzero=0
        for j in range (0,length):
            if (exponents[j] == 0):
                nbzero+=1
        if nbzero >= number_min_Zero:
            for j in range (0,length):
                print(exponents[j],end='\t')
            print(nbzero,end='\t')
            print(int(result*1000000000))
            nbSolutions = nbSolutions + 1
    
    # Add + Exponents Rotation
    exponents[0]+=1
    for j in range (0,length-1):
        if exponents[j]>exponent_minmax:
            exponents[j]=-exponent_minmax
            exponents[j+1]+=1
    if (progression_display):
        if (exponents[length-2]!=precedent):
            precedent=exponents[length-2]
            #print("Status:",end=' ')

print(exponents[j+1]);
print("All results lead to nbSolutions =", nbSolutions)
print("Precision", precision)
print("Used Values are:", values)

# %% [markdown]
# In the following example, one can write the equation with Latex:

# %%
from IPython.display import Latex
Latex(r"""\begin{eqnarray}
\frac{m_p^4}{m_p\cdot m_H\cdot\ m_e} = M  \\
\ R_U = \frac{2\cdot G\cdot M_U}{c^2} \\
\ M_U = \frac{({ħc}{G})^2}{m_em_pm_h} \\
\frac{r_H}{ƛ_e} = \frac{\sum\frac{1}{n}}{\sum\frac{1}{n^2}}\\
\end{eqnarray}""")
# Out:
# \begin{eqnarray}
# \frac{m_p^4}{m_p\cdot m_H\cdot\ m_e} = M  \\
# \ R_U = \frac{2\cdot G\cdot M_U}{c^2} \\
# \ M_U = \frac{({ħc}{G})^2}{m_em_pm_h} \\
# \frac{r_H}{ƛ_e} = \frac{\sum\frac{1}{n}}{\sum\frac{1}{n^2}}\\
# \end{eqnarray}

# %% [markdown]
# :star:
#
# # Docs
#
# This project aims at providing a repository dedicated to Dr Francis Michel Sanchez's work in holography and cosmology; it is just a mere continuation of what was initiated and published on a couple of other blogs.
#
# ## Blog
# * [cosmhology blog in english](https://cosmhology.blogspot.com/)
# * [cosmhologie blog in french](https://cosmhologie.blogspot.com/)
# * [Concorde Physiques in russian ](http://concorde-physiques.blogspot.com/)
#
# ## Publications
# * Please, cite this paper (http://vixra.org/pdf/1811.0146v8.pdf) if you employ this package in your research work.
# * [Vixra Publications](http://vixra.org/author/francis_m_sanchez)
# * [Rxiv Publications](http://rxiv.org/author/f_m_sanchez)
# * [A coherent resonant cosmology approach and its implications in microphysics and Biophysics Pages 375-407 of Quantum Systems in Physics, Chemistry](https://www.springer.com/fr/book/9783319502540?token=gbgen&wt_mc=GoogleBooks.GoogleBooks.3.EN#)
# * [From Coherent Cosmic Oscillations to the Steady-State Cyclic Ultrafast](https://rxiv.org/abs/1401.0228)
# * [Evidence for a Steady-State, Holographic, Tachyonic and Super-Symmetric Cosmology](https://www.researchgate.net/publication/267430152_Evidence_for_a_Steady-State_Holographic_Tachyonic_and_Super-Symmetric_Cosmology)
# * [academia.edu Correcting Five Historical Faults in Modern Cosmology](https://www.academia.edu/30843365/Correcting_Five_Historical_Faults_in_Modern_Cosmology)
#
# ## Videos
#
# * [L'enigme des grands nombres Part1](https://www.youtube.com/watch?v=ev_eIqLtK8s)
# * [L'enigme des grands nombres Part2](https://www.youtube.com/watch?v=i4w392nYqns)
# * [L'enigme des grands nombres Part3](https://www.youtube.com/watch?v=b4WvI0yVXnE)
# * [Exposés de Francis Sanchez playlist created by J.Bailhache](https://www.youtube.com/playlist?list=PLQXUNrzoAeFbmfHo3jgWzzExlVoBn2JUw)
# * [Khelif/Torgoz/Sanchez' Debate on LE FORMALISME EN PHYSIQUE ET EN SCIENCE](https://www.youtube.com/watch?v=TEK2hCI2we0)
#
# * [La science du 3eme millenaire playlist created by J.Bailhache](https://www.youtube.com/playlist?list=PLQXUNrzoAeFbLOuEsltAUWJWCcAEgeGJE)
# * [Francis Sanchez Cosmologie 23/03/2017](https://www.youtube.com/watch?v=NmvvIQjxBw8)
# * [La complexité mathématique face à la simplicité cosmique - Exposé de Francis Sanchez](https://www.youtube.com/watch?v=dyUlUahgHGg)
# * [La méthode scientifique en question et les constantes fondamentales - Exposé](https://www.youtube.com/watch?v=zUt1hxTdiuA)
# * [Jean Maruani chez lui et Francis Sanchez autour du nombre 237 29. 12. 17](https://www.youtube.com/watch?v=05g416VWjnw)
# * [Pr. Michel Grosmann: Holographie quanto-cosmique](https://www.youtube.com/watch?v=M7bJnekDIt0)
# * [Pr. Renée Veysseyre: La constante d'Atiyah réunifie Physique et Mathématique](https://www.youtube.com/watch?v=mbPpKqakDAU)
# * [Christian Bizouard, astronome: Omniprésence astrophysique du cycle de Kotov](https://www.youtube.com/watch?v=DGeBC73kKvQ)
# * [Pr. Francis Sanchez: Historique, Principe Calculatoire, Axe Topologique et Principe Holique](https://www.youtube.com/watch?v=IgKSrfsqFEs)
#
# ## Books
#
# * [Bizouard, Kotov, Sanchez wrote in 20th Natural Philosophy Alliance Proceedings by David de Hilster, published by Lulu.com in 2013]()
# * [Quantum Systems in Physics, Chemistry, Springer Ed](https://www.amazon.com/gp/search?index=books&linkCode=qs&keywords=9783319502557)
# * [The Worldwide List of Alternative Theories and Critics](https://books.google.com/books?isbn=2902425171)
# * [The Dirac Electron: From Quantum Chemistry to Holistic Cosmology by J.Maruani](https://onlinelibrary.wiley.com/doi/abs/10.1002/jccs.201500374#)
# * [solar 22 years cycle](https://link.springer.com/article/10.1007%2Fs10509-016-2985-8)
# * [Current Issues in Cosmology](https://www.cambridge.org/gb/academic/subjects/physics/cosmology-relativity-and-gravitation/current-issues-cosmology?format=HB&isbn=9780521858984)
# * ```@inproceedings{Sanchez2015RemarkablePO,
#   title=Remarkable Properties of the Eddington Number 137 and Electric Parameter 137 . 036 excluding the Multiverse Hypothesis},
#   author={Francis M. Sanchez and Valery A. Kotov,
#   year=2015```
#
# ## Papers
#
# * [College de France (2004): Discussions sur les oscillations cosmiques, les nombres sans dimension et les periodicites en microphysique et cosmologie - College de France 27th Feb 2004](https://lempel.pagesperso-orange.fr/occ_cdf.pdf)
#
# More to come soon stay tuned.../.:stars:.

# %%
#Write your equation in a dedicated cell with latex

from IPython.display import Latex
Latex(r"""\begin{eqnarray}
\frac{m_p^4}{m_p\cdot m_H\cdot\ m_e} = M \\
\frac{\pi_Pt}{\pi_Bb} = 6 \cdot \frac{\pi^5}{p_H^9} \\
\end{eqnarray}""")
# Out:
# \begin{eqnarray}
# \frac{m_p^4}{m_p\cdot m_H\cdot\ m_e} = M \\
# \frac{\pi_Pt}{\pi_Bb} = 6 \cdot \frac{\pi^5}{p_H^9} \\
# \end{eqnarray}

# %%
#Write Bekenstein-Hawking Entropy 
from IPython.display import Latex
Latex(r"""\begin{eqnarray}
S = \frac{c^3 k A}{4 \hbar G} \\
\end{eqnarray}""")
# Out:
# \begin{eqnarray}
# S = \frac{c^3 k A}{4 \hbar G} \\
# \end{eqnarray}
